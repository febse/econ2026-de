# %% [markdown]
# - `sex`: M: Mann, F: Frau
# - `drug`: Y: Ja, N: Nein
# - `ha`: Herzanfall Y: Ja, N: Nein

# %%
import pandas as pd
import matplotlib.pyplot as plt


dt = pd.read_csv("https://github.com/febse/econ2026/raw/refs/heads/main/data/ggb.csv")

dt.head()
# Out:
#   sex drug  ha
# 0   F    N   1
# 1   M    N   1
# 2   M    N   1
# 3   M    N   1
# 4   M    N   1

# %%
from statsmodels.formula.api import ols

# model1 = ols("", data=dt).fit()
# model1.summary()

# %% [markdown]
# Die folgenden Beobachtungen wurden über Gemeinden (counties) in Florida gemacht:
#
# - `C`: Anzahl der Verbrechen pro 100.000 Einwohner
# - `HS`: Anteil der Einwohner mit High School Abschluss
# - `U`: Anteil der Einwohner in urbanen Gebieten

# %%
# Read the data
crime = pd.read_csv("https://raw.githubusercontent.com/febse/data/main/econ/crime.csv", delimiter="\t")

# Drop the 'I' column
crime = crime.drop(columns=['I'])
crime.head()
# Out:
#      County    C    HS     U
# 0   ALACHUA  104  82.7  73.2
# 1     BAKER   20  64.1  21.5
# 2       BAY   64  74.7  85.0
# 3  BRADFORD   50  65.0  23.2
# 4   BREVARD   64  82.3  91.9
